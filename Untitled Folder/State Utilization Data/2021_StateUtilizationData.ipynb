# %%
import pandas as pd
df = pd.read_csv(r"C:\ERICS_STUFF\StateDrugUtilization\2021_StateDrugUtilizationData.csv") #.query("state=XX")  #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"

# df.sort_values(by=['state'])

only_xx = df[(df['state']=='XX') & (df['total_amount_reimbursed'] > 0)]

sum_total_reimbursed = sum(only_xx['total_amount_reimbursed'])
print(f'Total Amount Reimbursed is: {sum_total_reimbursed}')
display(only_xx)
# Out:
# Total Amount Reimbursed is: 18515633695.81996
#        utilization_type state          ndc  labeler_code  product_code  \
# 223326             FFSU    XX  17478051919         17478           519
# 225699             FFSU    XX  62175026146         62175           261
# 226371             FFSU    XX  68382099801         68382           998
# 228268             FFSU    XX  60846080901         60846           809
# 228387             MCOU    XX    378052393           378           523
# ...                 ...   ...          ...           ...           ...
# 395816             MCOU    XX  68645019159         68645           191
# 395818             MCOU    XX  69097081803         69097           818
# 395822             MCOU    XX  70677006001         70677            60
# 395829             MCOU    XX  68382099802         68382           998
# 395838             MCOU    XX  69918070001         69918           700
#
# ...
